# %% [markdown]
# # Análisis exploratorio de datos (EDA)

# %%
import pandas as pd

# %%
url_csv = 'https://raw.githubusercontent.com/DnRiv/FlightOnTime-/refs/heads/main/proyecto_hackathon/ds/data/Sample_DelayedFlights.csv'

# %%
df = pd.read_csv(url_csv)
df.head(5)
# Out:
#    Unnamed: 0  Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  \
# 0           0  2008      1           3          4   2003.0        1955
# 1           1  2008      1           3          4    754.0         735
# 2           2  2008      1           3          4    628.0         620
# 3           4  2008      1           3          4   1829.0        1755
# 4           5  2008      1           3          4   1940.0        1915
#
#    ArrTime  CRSArrTime UniqueCarrier  ...  TaxiIn TaxiOut  Cancelled  \
# 0   2211.0        2225            WN  ...     4.0     8.0          0
# 1   1002.0        1000            WN  ...     5.0    10.0          0
# 2    804.0         750            WN  ...     3.0    17.0          0
# 3   1959.0        1925            WN  ...     3.0    10.0          0
# 4   2121.0        2110            WN  ...     4.0    10.0          0
#
#    CancellationCode  Diverted  CarrierDelay  WeatherDelay NASDelay  \
# ...

# %% [markdown]
# Restraso

# %%
df["is_delayed"] = (df["ArrDelay"] > 15).astype(int)
df["is_delayed"].value_counts(normalize=True)
# Out:
# is_delayed
# 1    0.618962
# 0    0.381038
# Name: proportion, dtype: float64

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Year', 'Month', 'DayofMonth', 'DayOfWeek', 'DepTime',
#        'CRSDepTime', 'ArrTime', 'CRSArrTime', 'UniqueCarrier', 'FlightNum',
#        'TailNum', 'ActualElapsedTime', 'CRSElapsedTime', 'AirTime', 'ArrDelay',
#        'DepDelay', 'Origin', 'Dest', 'Distance', 'TaxiIn', 'TaxiOut',
#        'Cancelled', 'CancellationCode', 'Diverted', 'CarrierDelay',
#        'WeatherDelay', 'NASDelay', 'SecurityDelay', 'LateAircraftDelay',
#        'is_delayed'],
#       dtype='object')

# %%
'''
Variables MVP

Usaremos solo variables que:
- Existen antes del despegue
- Las puede entregar backend

Variables :
- UniqueCarrier
- Origin
- Dest
- CRSDepTime
- DayOfWeek
- Distance
'''
# Out:
# '\nVariables MVP\n\nUsaremos solo variables que:\n- Existen antes del despegue\n- Las puede entregar backend\n\nVariables :\n- UniqueCarrier\n- Origin\n- Dest\n- CRSDepTime\n- DayOfWeek\n- Distance\n'

# %%
'''
## Conclusiones

Este EDA define un MVP simple y funcional.

Siguientes pasos:
- Implementar las transformaciones definidas en preprocessing.py
- Entrenar un modelo base de clasificación
- Exponer el modelo vía FastAPI

'''
# Out:
# '\n## Conclusiones\n\nEste EDA define un MVP simple y funcional.\n\nSiguientes pasos:\n- Implementar las transformaciones definidas en preprocessing.py\n- Entrenar un modelo base de clasificación\n- Exponer el modelo vía FastAPI\n\n'
